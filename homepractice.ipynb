# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('dhaka.xlsx')
df
# Out:
#           EST  Temperature(C)  DewPoint(F)  Humidity(Kg/m3)  \
# 0    1/1/2016              38           23               52
# 1    1/2/2016              36           18               46
# 2    1/3/2016              40           21               47
# 3    1/4/2016              25            9               44
# 4    1/5/2016              20           -3               41
# 5    1/6/2016              33            4               35
# 6    1/7/2016              39           11               33
# 7    1/8/2016              39           29               64
# 8    1/9/2016              44           38               77
# 9   1/10/2016              50           46               71
# 10  1/11/2016              33            8               37
# 11  1/12/2016              35           15               53
# 12  1/13/2016              26            4               42
# 13  1/14/2016              30           12               47
# 14  1/15/2016              43           31               62
# ...

# %%
df.columns
# Out:
# Index(['EST', 'Temperature(C)', 'DewPoint(F)', 'Humidity(Kg/m3)',
#        'Sea Level Pressure(Pa)', 'VisibilityMiles(Miles)', 'WindSpeed(MPH)',
#        'CloudCover(Km)', 'City(BD)', 'Population(Million)', 'SeaDistance(Km)',
#        'Transport', 'Events'],
#       dtype='object')

# %%
df.to_csv('Selim_Hossain_Data.csv', index_label= False)

# %%
dff = pd.read_csv('Selim_Hossain_data.csv')
dff
# Out:
#           EST  Temperature(C)  DewPoint(F)  Humidity(Kg/m3)  \
# 0    1/1/2016              38           23               52
# 1    1/2/2016              36           18               46
# 2    1/3/2016              40           21               47
# 3    1/4/2016              25            9               44
# 4    1/5/2016              20           -3               41
# 5    1/6/2016              33            4               35
# 6    1/7/2016              39           11               33
# 7    1/8/2016              39           29               64
# 8    1/9/2016              44           38               77
# 9   1/10/2016              50           46               71
# 10  1/11/2016              33            8               37
# 11  1/12/2016              35           15               53
# 12  1/13/2016              26            4               42
# 13  1/14/2016              30           12               47
# 14  1/15/2016              43           31               62
# ...
